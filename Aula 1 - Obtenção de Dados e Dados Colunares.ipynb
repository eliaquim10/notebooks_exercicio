# %% [markdown]
# # **RESIDÊNCIAS EM VISÃO COMPUTACIONAL E ENGENHARIA E CIÊNCIA DE DADOS**
#
# # **Introdução à Ciência de Dados**
#
# ![WhatsApp Image 2021-10-04 at 9.51.51 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Exercícios #1
#
# As atividades neste notebook buscam colocar em prática os conceitos relacionados à obtenção e utilização de dados colunares.
#
# ### 1. Visite alguns dos repositórios de dados abaixo:
# > * https://opendatasus.saude.gov.br/
# > * http://dados.recife.pe.gov.br/
# > * https://opendata.cityofnewyork.us/
# > * https://github.com/awesomedata/awesome-public-datasets
#
# ### 2. **Selecione alguma base de sua preferência de cada repositório**.

# %% [markdown]
# ### 3. Carregue os dados Utilizando o pandas
# **Dica**: Utilize a função *read_csv* (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
# Dataset 1
# [CÓDIGO AQUI]
import pandas as pd
# import numpy as np

# dataset_ubs = pd.read_csv("https://rest-demas.saude.gov.br/api/estabelecimento", error_bad_lines=False ) #  
# dataset_ubs.head(2) não conseguir

# %%
# Dataset 2
# [CÓDIGO AQUI] recife
# dataset  = pd.read_json("http://dados.recife.pe.gov.br/dataset/eb9b8a72-6e51-4da2-bc2b-9d83e1f198b9/resource/b4c77553-4d25-4e3a-adb2-b225813a02f1/download/empresas-da-cidade-do-recife-atividades.json")
dataset_empresas = pd.read_csv("empresas_atividades.csv", encoding = "utf-8", sep='\n', delimiter=';') #  error_bad_lines=False,
dataset_empresas.head(2)
# Out:
#    cod_empresa                    razao_social  cod_grupo  \
# 0         6439  COMPANHIA DE TERRENOS PRAZERES         10
# 1         9913  GRANDES ARMAZENS DO RECIFE S A         10
#
#                                 nome_grupo     cnae  \
# 0  REPRESENTACAO, AGENCIAMENTO, CORRETAGEM  6821802
# 1  REPRESENTACAO, AGENCIAMENTO, CORRETAGEM  6821802
#
#                      desc_atividade atividade_principal  \
# 0  CORRETAGEM NO ALUGUEL DE IMÓVEIS                   S
# 1  CORRETAGEM NO ALUGUEL DE IMÓVEIS                   S
#
#   atividade_vig_sanitaria atividade_predominante incomodo
# 0                       N                      S        N
# 1                       N                      S        N

# %%
# Dataset 3
# [CÓDIGO AQUI] openData não conseguir

# dataset_transport = pd.read_csv("https://data.cityofnewyork.us/Transportation/MTA-Data/mmu8-8w8b")
# dataset_transport.head(2)

# %%
# Dataset 4
# [CÓDIGO AQUI]  mob
dataset_mob = pd.read_csv("https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/HTTWYL/176e7aa657e-abb48a689291.orig?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27mmALL_073120_csv.csv&response-content-type=text%2Fcsv&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20211010T143702Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20211010%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=4a0c5dce9dc05240989181ee02368acdd1926b13e834594acdb4074705f2ccbc", error_bad_lines=False)
dataset_mob.head(2)

# %% [markdown]
# ### 4.  Comandos Básicos
# Utilize os comandos básicos do pandas para visualizar os dados, o número de colunas, número de linhas, os tipos das colunas.

# %% [markdown]
# #### **1 - Qual o número de colunas e linhas de cada dataset?**

# %%
# Dataset 1
# [CÓDIGO AQUI]
# Out:
# (664168, 10)

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas.shape
# Out:
# (664168, 10)

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]

dataset_mob.shape
# Out:
# (17145, 31)

# %% [markdown]
# #### **2 - Carregue apenas as 10 primeiras linhas de cada dataset**

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]

dataset_empresas.head(10)
# Out:
#    cod_empresa                                       razao_social  cod_grupo  \
# 0         6439                     COMPANHIA DE TERRENOS PRAZERES         10
# 1         9913                     GRANDES ARMAZENS DO RECIFE S A         10
# 2         3765              CORELLI COMERCIO E REPRESENTACAO LTDA         10
# 3         6909      CDC CENTRAL DE DESPACHOS E CONTABILIDADE LTDA          6
# 4         4103         JOCOAL J C ALBUQUERQUE REPRESENTACOES LTDA         10
# 5         3894                                      ROSEL PASCOAL         10
# 6         9348                               CAIXA SEGURADORA S A          9
# 7         9348                               CAIXA SEGURADORA S A          9
# 8         5669  INST DE EST PESQ E ORIENT DOS CULTOS AGRO UMBANDA         20
# 9         5124            BRASIL NORDESTE REPRESENTACOES LTDA EPP         10
#
#                                      nome_grupo     cnae  \
# 0       REPRESENTACAO, AGENCIAMENTO, CORRETAGEM  6821802
# ...

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob.head(10)
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
# 5  201990006  Canada     20  1990  North America        1              6
# 6  201991001  Canada     20  1991  North America        1              1
# 7  201991002  Canada     20  1991  North America        1              2
# 8  201992001  Canada     20  1992  North America        1              1
# 9  201993001  Canada     20  1993  North America        1              1
#
#    startday  startmonth  startyear  ...  protesterdemand4   stateresponse1  \
# 0      15.0         1.0     1990.0  ...               NaN           ignore
# ...

# %% [markdown]
# #### **3 - Carregue apenas as 10 últimas linhas de cada dataset**

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas[-10:]
# Out:
#                id           country  ccode  year   region  protest  \
# 17135  9102013001  Papua New Guinea    910  2013  Oceania        1
# 17136  9102014001  Papua New Guinea    910  2014  Oceania        1
# 17137  9102015000  Papua New Guinea    910  2015  Oceania        0
# 17138  9102016001  Papua New Guinea    910  2016  Oceania        1
# 17139  9102017001  Papua New Guinea    910  2017  Oceania        1
# 17140  9102017002  Papua New Guinea    910  2017  Oceania        1
# 17141  9102017003  Papua New Guinea    910  2017  Oceania        1
# 17142  9102018000  Papua New Guinea    910  2018  Oceania        0
# 17143  9102019000  Papua New Guinea    910  2019  Oceania        0
# 17144  9102020000  Papua New Guinea    910  2020  Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...  protesterdemand4  \
# 17135              1       2.0         8.0     2013.0  ...               NaN
# ...

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob[-10:]

# %% [markdown]
# #### **4 - Sumarize algumas estatísticas de cada dataset**
# OBS: verificar documentação do pandas

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas.describe()
# Out:
#          cod_empresa      cod_grupo          cnae
# count  664168.000000  664168.000000  6.641680e+05
# mean     5101.062508      17.234283  5.736438e+06
# std      2894.595630       9.116524  1.995510e+06
# min       100.000000       1.000000  1.113010e+05
# 25%      2599.000000      10.000000  4.665600e+06
# 50%      5092.000000      22.000000  4.923001e+06
# 75%      7595.000000      26.000000  7.319003e+06
# max     10123.000000      29.000000  9.900800e+06

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob.describe()
# Out:
#                  id         ccode          year       protest  protestnumber  \
# count  1.714500e+04  17145.000000  17145.000000  17145.000000   17145.000000
# mean   4.380888e+09    437.888189   2006.171654      0.888831       7.406299
# std    2.320550e+09    232.054953      8.987378      0.314351      11.854041
# min    2.019900e+08     20.000000   1990.000000      0.000000       0.000000
# 25%    2.202010e+09    220.000000   1998.000000      1.000000       1.000000
# 50%    4.342008e+09    434.000000   2007.000000      1.000000       3.000000
# 75%    6.512005e+09    651.000000   2014.000000      1.000000       8.000000
# max    9.102020e+09    910.000000   2020.000000      1.000000     143.000000
#
#            startday    startmonth     startyear        endday      endmonth  \
# count  15239.000000  15239.000000  15239.000000  15239.000000  15239.000000
# mean      15.455935      6.227836   2006.326465     15.580616      6.243520
# ...

# %% [markdown]
# #### **5 - Quais os tipos de dados em cada coluna**

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas.dtypes
# Out:
# cod_empresa                 int64
# razao_social               object
# cod_grupo                   int64
# nome_grupo                 object
# cnae                        int64
# desc_atividade             object
# atividade_principal        object
# atividade_vig_sanitaria    object
# atividade_predominante     object
# incomodo                   object
# dtype: object

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob.dtypes
# Out:
# id                         int64
# country                   object
# ccode                      int64
# year                       int64
# region                    object
# protest                    int64
# protestnumber              int64
# startday                 float64
# startmonth               float64
# startyear                float64
# endday                   float64
# endmonth                 float64
# endyear                  float64
# protesterviolence        float64
# location                  object
# participants_category     object
# participants              object
# protesteridentity         object
# protesterdemand1          object
# protesterdemand2          object
# protesterdemand3          object
# protesterdemand4          object
# stateresponse1            object
# stateresponse2            object
# stateresponse3            object
# stateresponse4            object
# stateresponse5            object
# stateresponse6            object
# ...

# %% [markdown]
# #### **6 - Verifique quantos valores existem em cada coluna**
# OBS: utilize value_counts()

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas.value_counts()
# Out:
# cod_empresa  razao_social                                       cod_grupo  nome_grupo                                    cnae     desc_atividade                                                                  atividade_principal  atividade_vig_sanitaria  atividade_predominante  incomodo
# 5077         BOM TOM COMÉRCIO DE CALÇADOS E BOLSAS LTDA         26         OUTRAS ATIVIDADES VAREJISTAS                  4755503  COMERCIO VAREJISTA DE ARTIGOS DE CAMA, MESA E BANHO                             N                    N                        N                       N           2
#                                                                                                                          4789001  COMÉRCIO VAREJISTA DE SUVENIRES, BIJUTERIAS E ARTESANATOS                       N                    N                        N                       N           2
# ...

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob['protesterviolence'].value_counts()
# Out:
# 0.0    11723
# 1.0     4035
# Name: protesterviolence, dtype: int64

# %% [markdown]
# #### **7 - Faça a seleção de dados dos datasets**
# OBS: Utilize as funções .loc[...] e .iloc[...]

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas['cnae'].value_counts().iloc[0:].hist()
# Out:
# <AxesSubplot:>

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob['protestnumber'].value_counts().loc[0:].hist()
# dataset_mob.head(2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### **8 - Utilizando operadores relacionais e lógicos (Ex: >, <, >=, <=, ==, &, |) para fazer a seleção de dados. Utilize pelo menos um desses para cada dataset.**

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
dataset_empresas['cnae'].value_counts()[(dataset_empresas['cnae'].value_counts() > 100)].hist()
# Out:
# <AxesSubplot:>

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
dataset_mob['protestnumber'].value_counts()[(dataset_mob['protestnumber'].value_counts() > 1)].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### **9 - Escolha pelo menos uma coluna de cada dataset e mostre seus valores únicos. Também mostre a quantidade de valores únicos.**

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
# dataset_empresas.columns
# dataset_empresas['cod_empresa'].unique()
print(dataset_empresas.shape)
print(dataset_empresas[dataset_empresas['cod_empresa'].duplicated()].shape)
# Out:
# (664168, 10)
# (654144, 10)

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
print(dataset_mob.shape)
print(dataset_mob[dataset_mob['ccode'].duplicated()].shape)
# dataset_mob['ccode'].duplicated()
# Out:
# (17145, 31)
# (16977, 31)

# %% [markdown]
# #### **10 - Escolha pelo menos uma coluna de cada dataset e utilize a operação .groupby() para agrupar todos os outros dados a partir da coluna em questão.**
# OBS: Para visualizar esse agrupamente realize operações de count(), sum(), or mean(), etc...

# %%
# Dataset 1
# [CÓDIGO AQUI]

# %%
# Dataset 2
# [CÓDIGO AQUI]
# print(dataset_empresas.shape)
dataset_empresas[['incomodo', 'cod_empresa']].groupby(by=['incomodo']).count()
# print(dataset_empresas.dtypes)
# Out:
#           cod_empresa
# incomodo
# N          2816253447
# S           571709037

# %%
# Dataset 3
# [CÓDIGO AQUI]

# %%
# Dataset 4
# [CÓDIGO AQUI]
# dataset_empresas[['incomodo', 'cod_empresa']].groupby(by=['incomodo']).count()
dataset_mob[['country', 'protest']].groupby(by=['country']).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c5fc89142e7f> in <module>
#       2 # [CÓDIGO AQUI]
#       3 # dataset_empresas[['incomodo', 'cod_empresa']].groupby(by=['incomodo']).count()
# ----> 4 dataset_mob[['country', 'protest']].groupby(by=['country']).sum()
#
# NameError: name 'dataset_mob' is not defined
