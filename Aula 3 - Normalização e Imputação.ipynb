# %% [markdown]
# # **RESIDÊNCIAS EM VISÃO COMPUTACIONAL E ENGENHARIA E CIÊNCIA DE DADOS**
#
# ## **Introdução à Ciência de Dados**
#
# ![WhatsApp Image 2021-10-04 at 9.51.51 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Exercícios #3
#
# As atividades neste notebook buscam colocar em prática os conceitos relacionados à análise descritivas dos dados, derivação de features, normalização de dados, visualização de dados, compreensão e aplicação de libraries.
#
# Uma base de dados de trajetórias de ônibus da cidade de Dublin será utilizada para este exercício.
#
# SRAG 2021 - Banco de Dados de Síndrome Respiratória Aguda Grave - incluindo dados da COVID-19
# FONTE: [link](https://opendatasus.saude.gov.br/dataset/9f76e80f-a2f1-4662-9e37-71084eae23e3)
#
# DATASET: https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2021/INFLUD21-04-10-2021.csv
#
# DICIONÁRIO DE DADOS: https://opendatasus.saude.gov.br/dataset/9f76e80f-a2f1-4662-9e37-71084eae23e3/resource/b3321e55-24e9-49ab-8651-29cf5c8f3179/download/dicionario_de_dados_srag_hospitalizado_23.03.2021.pdf

# %% [markdown]
# ###1- Acesse o link acima para carregar a base de dados.

# %%
# [CARREGUE OS DADOS AQUI]

# %% [markdown]
# ###2- Selecionem somente as colunas abaixo

# %%
# columns = ["DT_NOTIFIC", "DT_SIN_PRI",
#            "SG_UF_NOT", "ID_MUNICIP", "ID_REGIONA", 
#            "ID_UNIDADE", "CS_SEXO", "DT_NASC", 
#            "NU_IDADE_N", "TP_IDADE", 
#            "CS_GESTANT", "CS_RACA", "CS_ETINIA", 
#            "CS_ESCOL_N", 
#            "PAC_COCBO", "PAC_DSCBO", "FEBRE", 
#            "TOSSE", "GARGANTA", "DISPNEIA", 
#            "DESC_RESP", "SATURACAO", "DIARREIA", 
#            "VOMITO", "DOR_ABD", "FADIGA", "PERD_OLFT", 
#            "PERD_PALA", "OUTRO_SIN", "OUTRO_DES", 
#            "FATOR_RISC", "PUERPERA", "CARDIOPATI", 
#            "HEMATOLOGI", "SIND_DOWN", "HEPATICA", 
#            "ASMA", "DIABETES", "NEUROLOGIC", "PNEUMOPATI", 
#            "IMUNODEPRE", "RENAL", "OBESIDADE", "OBES_IMC", 
#            "OUT_MORBI", "VACINA_COV", "DOSE_1_COV", 
#            "DOSE_2_COV", "LOTE_1_COV", 
#            "LOTE_2_COV", "VACINA", "DT_UT_DOSE", "RAIOX_RES", 
#            "SUPORT_VEN", "RAIOX_OUT", "DT_RAIOX", "TOMO_RES", 
#            "TOMO_OUT", "AN_SARS2", "POS_PCRFLU", "PCR_SARS2", 
#            "PCR_RESUL", "TP_SOR", "OUT_SOR", "RES_IGG", "RES_IGM",
#            "RES_IGM", "DT_RES", "CLASSI_FIN", "CRITERIO"]

# [FAÇA AQUI UMA CÓPIA DO DATAFRAME SOMENTE COM AS COLUNAS ACIMA]

# %% [markdown]
# ### 3- Ajuste de tipos
# Ex:
# >
# > float64 -> float32
# >
# > int64 -> int32
# >
# > object -> datetime
#
# OBS: Para fazer o ajuste dos tipos *datetime*, perceba que ocorrerá erro devido a valores faltantes. Inicialmente, ignore esses dados faltantes. Eles são tratados posteriormente. Para isso aplique a conversão utilizando o atributo "*errors='coerce'*"

# %%
# [FAÇA O AJUSTES DE TIPOS AQUI]

# %% [markdown]
# ###3- Codifique as variáveis categóricas para discretas
# > Utilize o "cat.codes""
# >
# > Utilize a biblioteca (Sklearn)

# %%
# [AQUI, UTILIZE O CAT.CODES]

# %%
# [AQUI, UTILIZE LABEL ENCODER DO SCIKIT-LEARN]

# %% [markdown]
# ###4- Remoção de dados faltantes:
# > Deleção por linhas
# >
# > Deleção por colunas

# %%
# Deletar colunas que tenham mais de 1.2M de valores faltantes/nulos

# [FAÇA AQUI A DELEÇÃO POR COLUNAS]

# %%
# Deletar linhas que apresentem mais do que 48% das colunas faltantes (NaN..NAT..etc)

# [FAÇA AQUI A DELEÇÃO POR LINHAS]

# %% [markdown]
# ###5- Imputação de dados faltantes:
#
# >Média
# >
# >Mediana
# >
# >Moda

# %% [markdown]
# ####Faça a inputação de datas de nascimento
# > Utilize a função apply para iterar sobre as linhas
# >
# > Implemente a função abaixo para inferir as datas caso ela seja nula (NaT [Not a Time])

# %%
## DICA: to_datetime e DateOffset

# def infer_birthdate(dt, age):
#   [DESENVOLVA AQUI A FUNÇÃO]

# %% [markdown]
# #### Crie outro dataframe para cada estratégia de inputação (Média, Mediana e Moda)
# > Considerar as colunas OBES_IMC (numérico), FEBRE (categórico), RAÇA (categórico)
# >
# > Colunas catégoricas usem a MODA ou o valor *default* (Ignorado)

# %%
# [DESENVOLA A SOLUÇÃO AQUI]

# %% [markdown]
# #### Plote o box plot das colunas acima

# %%
# [DESENVOLA A SOLUÇÃO AQUI]

# %% [markdown]
# #### Plote o gráfico de Barras para a coluna RAÇA

# %%
# [DESENVOLA A SOLUÇÃO AQUI]

# %% [markdown]
# ###6- Discretização
# > Realize a discretização da coluna NU_IDADE_N de acordo com os seguintes grupos etários:
# >> Criança [0-13)
# >>
# >> Adolescentes [12-19)
# >>
# >> Jovens [19-29]
# >>
# >> Adultos [30-60)
# >>
# >> Idosos [60-150]

# %%
# [DESENVOLVA A SOLUÇÃO AQUI]

# %% [markdown]
# #### Plot o gráfico de barras para os grupos etários

# %%
# [DESENVOLVA A SOLUÇÃO AQUI]

# %% [markdown]
# ###7- Normalização
# >> Considerem as colunas NU_IDADE_N e OBES_IMC

# %%
# [PLOT O BOX PLOT PARA AS COLUNAS]

# %%
# [APLIQUE A NORMALIZAÇÃO PADRÃO (MÉDIA E DESVIO) ÀS COLUNAS]

# %%
# [PLOT O BOX PLOT PARA OS DADOS NORMALIZADOS ]

# %%
# [APLIQUE A NORMALIZAÇÃO MINMAX ÀS COLUNAS]

# %%
# [PLOT O BOX PLOT PARA OS DADOS NORMALIZADOS ]
